# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('movies_2.csv')
print(df)
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
df: df.drop(columns = ["Summary"])
print(df)
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
df.tail()
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
#             Gross Release Date      Genre  Runtime  Rating  Rating Count  \
# 611  1.062000e+09   2019-06-11  Animation    100.0     NaN           NaN
# 612  7.594000e+08   2019-07-13   Thriller    136.0     NaN           NaN
# 613  1.632000e+09   2019-07-09      Drama    118.0     NaN           NaN
# 614  2.796000e+09   2019-04-22     Action    181.0     NaN           NaN
# 615           NaN          NaN        NaN      NaN     NaN           NaN
#
#     Summary
# 611     NaN
# 612     NaN
# 613     NaN
# ...

# %%
#question 1
df.shape
# Out:
# (616, 11)

# %%
#It is now time to assess the data. This process includes gaining information such as:

#the number of rows and columns present in the data set (shape of the dataframe)

#df.shape done.

#columns present in the data set, along with the data type (info method or dtypes method)

#df.info done.

#check for MPAA Rating, Budget, Gross, Release Date, Genre, Runtime, Rating and Rating Count columns how many NaN we have

#df.isna().sum() done. 

#df[df.isnull().any(axis=1)]

#understanding which kind of information each column represents

#df.dtypes done.
#interjure, is numbers
#object, is Text or mixed numeric and non-numeric values
#float, is Floating point numbers

# %%
#Get rid of the Summary column (use the drop() method)

df.drop(labels=["Summary"], axis=1)
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
#use the rename method to change all columns names lowercase and add an underscore if they are made of 2 words

#I need to do this

# %%
#Get rid of the last row, the one containing NaN for each column (use drop() method and row index)

df.drop(labels=[615], axis=0, inplace=True)

# %%
#use fillna() method to replace the missing values of Rating with their median

#dont even understand the question, check the code review file

# %%
#Drop the duplicates, if any

df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
#
# ...

# %%
#Convert Budget into integer type (use astype() method)

#df["Budget"].astype("int", copy=False)

#This is not changing the original dataframe!

#This will change it:

#df["Budget"] = df["Budget"].astype("int")



#Convert Gross into integer type



#Convert Release Date into date type (use to_datetime method)

#check the documentation

#df["Release Date"] = pd.to_datetime(df["Release Date"], format= "%Y-%m-%d", errors="coerce")
#df.dtypes


#Why does this not work? I did not remove the last line. "coerce". Datetime, ignores errors?

# %%
#which Genre is favored the most by the people?

#based on what?

# %%
#most and least expensive Genre (take an average of all Budget measures grouped by Genre - use groupBy() method)

#I need to do this

# %%
#most & least frequent MPAA Rating in the dataset in terms of occurances

#I need to do this

# %%
#show the top 5 Comedy movies by Rating

new_comedy = df.loc[(df["Genre"] == "Comedy")]

new_comedy.sort_values(by=["Rating"], ascending=False)

#done!
# Out:
#      MovieID                          Title MPAA Rating       Budget  \
# 111      112                   Forrest Gump       PG-13   55000000.0
# 185      186                The Truman Show          PG   60000000.0
# 80        81                  Groundhog Day          PG   14600000.0
# 254      255                 Monsters, Inc.           G  115000000.0
# 316      317         The 40 Year Old Virgin           R   26000000.0
# ..       ...                            ...         ...          ...
# 516      517                Pitch Perfect 2       PG-13   29000000.0
# 537      538                       Deadpool           R   58000000.0
# 582      583                     Deadpool 2           R  110000000.0
# 597      598                     The Upside       PG-13   37500000.0
# 601      602  Once Upon a Time in Hollywood           R   96000000.0
#
#            Gross Release Date   Genre  Runtime  Rating  Rating Count  \
# ...

# %%
#top 5 expensive movies released after 1999, not included (measured by Budget)

exp_mov = df.loc[(df["Release Date"] > "2000")]
exp_mov
exp_mov.sort_values(["Budget"], ascending=False)
exp_mov.head(5)

#done
# Out:
#      MovieID                           Title MPAA Rating      Budget  \
# 98        99               Jurassic Park III       PG-13  93000000.0
# 217      218  Crouching Tiger, Hidden Dragon       PG-13  17000000.0
# 218      219                     Scary Movie           R  19000000.0
# 219      220               Big Momma's House       PG-13  30000000.0
# 220      221             Remember the Titans          PG  30000000.0
#
#            Gross Release Date     Genre  Runtime  Rating  Rating Count  \
# 98   368800000.0   2001-07-16  Thriller     92.0     8.9     1690474.0
# 217  213525736.0   2000-10-01   Romance    120.0     7.8      242878.0
# 218  278019771.0   2000-07-07    Comedy     88.0     6.2      219032.0
# 219  173959438.0   2000-05-31     Crime     98.0     5.1       77180.0
# 220  136706683.0   2000-09-29     Drama    113.0     7.8      186997.0
#
#                                                Summary
# 98    A decidedly odd couple with ulterior motives ...
# ...

# %%
#top 3 high Gross Romance movies released after 1999, not included (typecast it to datetime)

#I need to do this

# %%
#how many Genres are present in the dataframe? (use the function value_counts() which applies to Series, not Dataframe)

#I need to do this. use the .unique thingy.

# %%
#top 5 movie names by Rating

df.sort_values(by=["Rating"], ascending=False)
# Out:
#      MovieID                                          Title MPAA Rating  \
# 393      394                                The Dark Knight       PG-13
# 98        99                              Jurassic Park III       PG-13
# 287      288  The Lord of the Rings: The Return of the King       PG-13
# 99       100                                   Pulp Fiction           R
# 83        84                               Schindler's List           R
# ..       ...                                            ...         ...
# 610      611                 Godzilla: King of the Monsters       PG-13
# 611      612                                    Toy Story 4           G
# 612      613          Fast & Furious Presents: Hobbs & Shaw       PG-13
# 613      614                                  The Lion King          PG
# 614      615                              Avengers: Endgame       PG-13
#
#           Budget         Gross Release Date      Genre  Runtime  Rating  \
# ...

# %%
#show the movies with more than 7 in Rating & greater than 50 million Gross

df[(df["Gross"] > 50000000) & (df["Rating"] > 7.0)]
# Out:
#      MovieID                                Title MPAA Rating       Budget  \
# 1          2                   Driving Miss Daisy          PG    7500000.0
# 2          3                       Turner & Hooch          PG   13000000.0
# 3          4           Born on the Fourth of July           R   14000000.0
# 4          5                      Field of Dreams          PG   15000000.0
# 6          7              When Harry Met Sally...           R   16000000.0
# ..       ...                                  ...         ...          ...
# 505      506                           Big Hero 6          PG  165000000.0
# 506      507                         Interstellar       PG-13  165000000.0
# 507      508  Captain America: The Winter Soldier       PG-13  170000000.0
# 508      509       Dawn of the Planet of the Apes       PG-13  170000000.0
# 509      510              Guardians of the Galaxy       PG-13  170000000.0
#
# ...

# %%
#show the movies with more than 7 in Rating & greater than 50 million Gross & with Parental guidance as MPAA Rating

df[(df["Gross"] > 50000000) & (df["Rating"] > 7.0) & (df["MPAA Rating"] == "PG")]
# Out:
#      MovieID                                     Title MPAA Rating  \
# 1          2                        Driving Miss Daisy          PG
# 2          3                            Turner & Hooch          PG
# 4          5                           Field of Dreams          PG
# 7          8                        Dead Poets Society          PG
# 13        14                                    Batman          PG
# 15        16                        The Little Mermaid          PG
# 16        17                Back to the Future Part II          PG
# 19        20                           Steel Magnolias          PG
# 24        25                                Home Alone          PG
# 32        33                  The Hunt for Red October          PG
# 34        35               Back to the Future Part III          PG
# 45        46           Teenage Mutant Ninja Turtles II          PG
# 46        47                      Beauty and the Beast          PG
# ...

# %%
#count of Animation movies with more than 7 in Rating (use the shape() function)

df[(df["Genre"] == "Animation") & (df["Rating"] > 7.0)]

#works

#df.shape
    
#does not work
# Out:
#      MovieID                             Title MPAA Rating       Budget  \
# 15        16                The Little Mermaid          PG   40000000.0
# 46        47              Beauty and the Beast          PG   25000000.0
# 65        66                           Aladdin           G   28000000.0
# 107      108                     The Lion King           G   45000000.0
# 123      124                         Toy Story           G   30000000.0
# 171      172                          Hercules           G   85000000.0
# 188      189               The Prince of Egypt          PG   70000000.0
# 191      192                             Mulan           G   90000000.0
# 194      195                      A Bug's Life           G  120000000.0
# 211      212                       Toy Story 2           G   90000000.0
# 215      216                            Tarzan          PG  150000000.0
# 241      242                             Shrek          PG   60000000.0
# ...

# %%
#show the list of top 5 movies based on Budget

final = df.sort_values(("Budget"), ascending=False)
final.head()
# Out:
#      MovieID                                        Title MPAA Rating  \
# 594      595                       Avengers: Infinity War       PG-13
# 454      455  Pirates of the Caribbean: On Stranger Tides       PG-13
# 614      615                            Avengers: Endgame       PG-13
# 574      575                     Star Wars: The Last Jedi       PG-13
# 375      376     Pirates of the Caribbean: At World's End       PG-13
#
#           Budget         Gross Release Date            Genre  Runtime  Rating  \
# 594  400000000.0  2.048000e+09   2018-04-23           Action    149.0     NaN
# 454  380000000.0  1.045714e+09   2011-05-14           Action    136.0     6.6
# 614  356000000.0  2.796000e+09   2019-04-22           Action    181.0     NaN
# 574  317000000.0  1.333000e+09   2019-12-09  Science Fiction    152.0     NaN
# 375  300000000.0  9.610000e+08   2007-05-19        Adventure    169.0     7.1
#
#      Rating Count                                            Summary
# ...

# %%
# use sort, create new category

#I need to do this
